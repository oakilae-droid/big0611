# %% [markdown]
# ### 연산자
# ##### 1. 산술 연산자

# %%
a = 10
b = 3
print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b)
print(a ** b)
print(a % b)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1000
# 1

# %% [markdown]
# #### 2. 비교 연산자
# - \> 크다(초과)
# - < 작다(미만)
# - \>= 크거나 같다(이상)
# - <= 작거나 같다(이하)
# - == 같다
# - != 같지 않다

# %%
print(a > b)    # True
print(a < b)    # False
print(a >= b)   # True
print(a <= b)   # False
print(a == b)   # False
print(a != b)   # True
# Out:
# True
# False
# True
# False
# False
# True

# %% [markdown]
# #### 3. 논리 연산자
# - and(논리곱)
# - or(논리합)
# - not(논리부정)

# %%
# and는 모든 조건이 모두 참일때 True
print((10 > 5) and (3 < 1) and (5 > 1))     # False
# or는 모든 조건이 거짓일때만 False
print((10 > 5) or (3 < 1) or (4 < 1))       # True
# and가 or보다 우선순위가 높다.
print((10 > 5) or (3 < 1) and (4 < 1))      # True
print(not (10 > 5))                         # False
# Out:
# False
# True
# True
# False

# %% [markdown]
# #### 4. 대입 연산자

# %%
# 5를 x에 대입
# 오른쪽 값을 왼쪽에 대입
# 변수: x, a, b
x = 5
# 5 = x -> SyntaxError
# b의 값을 a에 대입
a = b

# %% [markdown]
# #### 5. 복합 대입 연산자
# - +=
# - -=
# - *=
# - /=
# - %=
# - //=
# - **=

# %%
x = 5
x += 1  # x = x + 1
# 파이썬은 ++, --는 없다.
print(x)
x += 3  # x = x + 3
print(x)
x -= 3  # x = x - 3
print(x)
x *= 3  # x = x * 3
print(x)
x /= 3  # x = x / 3
print(x)
x //= 3 # x = x // 3
print(x)
x %= 3  # x = x % 3
print(x)
x **= 3 # x = x ** 3
print(x)
# Out:
# 6
# 9
# 6
# 18
# 6.0
# 2.0
# 2.0
# 8.0

# %% [markdown]
# #### 6. 멤버십 연산자
# - in: 값이 안에 있으면 True
# - not in: 값이 안에 없으면 True

# %%
fruits = ["사과", "바나나", "체리"]     # 리스트
print("바나나" in fruits)   # True
print("오렌지" in fruits)   # False
# Out:
# True
# False

# %% [markdown]
# #### 정수와 실수 연산

# %%
a = 5
b = 5.5
# 정수 + 실수 -> 실수
a + b

# shift + enter: 실행(아래에 셀이 없으면 셀을 만들고 실행)
# ctrl + enter: 실행(셀을 만들지 않고 실행)
# alt + enter: 실행(무조건 아래에 셀을 만들고 실행)
# Out:
# 10.5

# %%
# 코드 작성: 커서 깜빡임
# 셀 편집: Esc
print("Hello")
# Out:
# Hello
