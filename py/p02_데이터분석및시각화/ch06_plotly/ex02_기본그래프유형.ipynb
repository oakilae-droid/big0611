# %% [markdown]
# # 기본 그래프 유형
# ## 선 그래프(line plot)

# %%
import plotly.express as px
import pandas as pd
import numpy as np

# %%
# 시계열 데이터 생성
# 2024-01-01 부터 D(Daily) 하루씩 30일간
dates = pd.date_range('2024-01-01', periods=30, freq='D')
# np.random.randn(30): 평균 0, 표준편차 1에 따른 난수 30개
values = np.cumsum(np.random.randn(30)) + 100

time_series = pd.DataFrame({
    '날짜': dates,
    '주가': values
})
time_series
# Out:
#            날짜          주가
# 0  2024-01-01   99.864854
# 1  2024-01-02   99.720346
# 2  2024-01-03   98.903600
# 3  2024-01-04   99.045971
# 4  2024-01-05   99.134470
# 5  2024-01-06   98.713469
# 6  2024-01-07   97.224198
# 7  2024-01-08   97.787421
# 8  2024-01-09   97.275208
# 9  2024-01-10   97.817400
# 10 2024-01-11   99.236001
# 11 2024-01-12   99.343662
# 12 2024-01-13   98.683970
# 13 2024-01-14   97.668035
# 14 2024-01-15   97.606738
# 15 2024-01-16   98.789656
# 16 2024-01-17   98.766445
# 17 2024-01-18  100.536563
# 18 2024-01-19  101.175405
# 19 2024-01-20  101.800580
# 20 2024-01-21  103.285844
# 21 2024-01-22  102.806529
# 22 2024-01-23  103.544784
# 23 2024-01-24  103.852400
# 24 2024-01-25  103.341940
# 25 2024-01-26  102.913663
# 26 2024-01-27  102.441833
# 27 2024-01-28  101.589097
# 28 2024-01-29   99.769305
# 29 2024-01-30   97.910085

# %%
fig = px.line(
    time_series,
    x='날짜',
    y='주가',
    title='일일 주가 변동',
    markers=True
)
fig.show()

# %%
# 2. 다중 선 그래프
companies = ['삼성전자', 'LG전자', 'SK하이닉스']
stock_data = []

for company in companies:
    for i, date in enumerate(dates):
        price = 100 + np.cumsum(np.random.randn(1))[0] * (i + 1) / 10
        stock_data.append({
            '날짜': date,
            '회사': company,
            '주가': price
        })
df_stocks = pd.DataFrame(stock_data)
df_stocks
# Out:
#            날짜      회사          주가
# 0  2024-01-01    삼성전자   99.996462
# 1  2024-01-02    삼성전자  100.228620
# 2  2024-01-03    삼성전자   99.841784
# 3  2024-01-04    삼성전자  100.126603
# 4  2024-01-05    삼성전자   99.940592
# ..        ...     ...         ...
# 85 2024-01-26  SK하이닉스  107.984298
# 86 2024-01-27  SK하이닉스  101.571463
# 87 2024-01-28  SK하이닉스  101.310573
# 88 2024-01-29  SK하이닉스   98.158809
# 89 2024-01-30  SK하이닉스  103.597068
#
# [90 rows x 3 columns]

# %%
# 데이터 시각화
fig = px.line(
    df_stocks,
    x='날짜',   # x축 컬럼명
    y='주가',   # y축 컬럼명
    color='회사',   # 그룹별 색상
    title='회사별 주가 비교',   # 그래프 제목
    line_dash='회사'    # 선 스타일
)
fig

# %% [markdown]
# # 산점도(scatter plot)

# %%
# 1. 기본 산점도
# 키와 몸무게 데이터
height_weight = {
    '키': [160, 165, 170, 175, 180, 162, 168, 172, 178, 185],
    '몸무게': [55, 60, 65, 70, 75, 58, 63, 68, 73, 80],
    '성별': ['여성', '여성', '여성', '남성', '남성', '여성', '여성', '남성', '남성', '남성']
}

df_body = pd.DataFrame(height_weight)
df_body
# Out:
#      키  몸무게  성별
# 0  160   55  여성
# 1  165   60  여성
# 2  170   65  여성
# 3  175   70  남성
# 4  180   75  남성
# 5  162   58  여성
# 6  168   63  여성
# 7  172   68  남성
# 8  178   73  남성
# 9  185   80  남성
