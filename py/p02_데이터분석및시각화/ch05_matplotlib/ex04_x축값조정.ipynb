# %%
import matplotlib.pyplot as plt

# 1. x, y 데이터
x = [10, 20, 30]
y = [15, 24, 18]

plt.bar(x, y, width=5)
# xlim: x축 limit(범위)
plt.xlim(0, 40)
# plt.xticks([0, 5, 10, 15, 20, 25, 30, 35, 40])
plt.xticks(range(0, 41, 5))
# Out:
# ([<matplotlib.axis.XTick at 0x1780d5a0390>,
# ...
#  [Text(0, 0, '0'),
#   Text(5, 0, '5'),
#   Text(10, 0, '10'),
#   Text(15, 0, '15'),
#   Text(20, 0, '20'),
#   Text(25, 0, '25'),
#   Text(30, 0, '30'),
#   Text(35, 0, '35'),
#   Text(40, 0, '40')])
