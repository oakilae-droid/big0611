# %% [markdown]
# # 파일 변환(ipynb -> py)

# %%
print('ipynb를 py로 변환 성공!')
# Out:
# ipynb를 py로 변환 성공!

# %%
'ipynb를 py로 변환 성공!'
# Out:
# 'ipynb를 py로 변환 성공!'

# %%
print('ipynb를 py로 변환 성공!')
# Out:
# ipynb를 py로 변환 성공!
