# %% [markdown]
# ## 패키지는 1개 이상의 모듈로 구성
# ## 모듈은 하나의 파이썬 파일(.py)
# ## 모듈은 클래스와 함수로 구성
# ## 패키지 불러오기
# import 패키지이름 예) import bs4
#
# import 패키지이름 as 별명 예) import bs4 as bs
#
# from 패키지이름 import 함수 예) from bs4 import BeautifulSoup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 배열
np.arange(10)

# %%
pd.DataFrame({
    'col1': [1, 2],
    'col2': [3, 4]
})
