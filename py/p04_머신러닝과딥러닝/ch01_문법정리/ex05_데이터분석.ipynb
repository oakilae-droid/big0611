# %% [markdown]
# ## 데이터 분석
# ### 배열(NumPy)
# ### 데이터프레임(Pandas)

# %%
# 리스트(List)
lst = list(range(10))
print(lst)
print(lst * 2)

result = []
for num in lst:
    result.append(num * 2)
print(result)

# %%
import numpy as np
# 배열(Array)
arr = np.arange(10)
print(arr)
print(arr * 2)

# %%
import pandas as pd
import seaborn as sns

df = sns.load_dataset('tips')
df.head()

# %%
df.info()

# %%
# 결측치 개수 확인
df.isna().sum()

# %%
print(True + True)
print(True + False)
print(False + False)

# %%
# 주요 통계 지표(숫자 타입)
# 개수(count), 평균(mean), 표준편차(std), 최솟값(min), 분위수(25%, 50%, 75%), 최댓값(max)
df.describe()

# %%
# 중복값 확인
df.duplicated().sum()

# %%
df[df.duplicated()]

# %%
# 카테고리 타입의 값 확인
df['day'].unique()

# %%
# smoker 유형에 따라 각 수치형 변수의 평균값 출력
# Pandas 2.0 버전 이후는 카테고리 유형이 자동 배제되지 않는다.
df.groupby(['smoker']).mean(numeric_only=True)

# %%
# !pip list

# %%
# !pip show pandas

# %%
# 머신러닝 알고리즘은 모든 데이터가 수치형 데이터일 경우에만 학습 가능
# 원핫 인코딩 -> 카테고리형 데이터를 수치형 데이터로 변환
pd.get_dummies(df, dtype=int)
